# %%
using Plots

# %%
p = zeros(1000)
q = zeros(Bool, 1000)
p[1] = √2
q[1] = true

for i in 2:1000
    p[i] = sqrt(2.0+sqrt(p[i-1]))
    q[i] = (p[i] ≥ sqrt(3)/2/sqrt(2)*p[i-1])
end

# %%
θ = -π:0.01:π
plot(θ, abs.(θ).-abs.(sin.(θ)))

# %%
t=1:100
f(t) = t/(1+t^2)
plot(t, f.(t))
